# %%
import subprocess
import os

# Set up environment with correct JAVA_HOME
env = os.environ.copy()
env['JAVA_HOME'] = '/opt/homebrew/opt/openjdk@17/libexec/openjdk.jdk/Contents/Home'

result = subprocess.run(
    ["/Users/hungnguyen/dacn/untitled folder/gumtree-4.0.0-beta4/bin/gumtree", "--help"],
    capture_output=True,
    text=True,
    encoding='utf-8',
    errors='replace',
    timeout=10,
    env=env
)

print(result)
# Out:
# CompletedProcess(args=['/Users/hungnguyen/dacn/untitled folder/gumtree-4.0.0-beta4/bin/gumtree', '--help'], returncode=0, stdout='Available Options:\n-C <2>\tSet system property (-c property value). \n-v\tVerbose mode\n--help\tDisplay help (this screen).\n\nAvailable Commands:\n', stderr='No command given.\nAvailable Options:\n-C <2>\tSet system property (-c property value). \n-v\tVerbose mode\n--help\tDisplay help (this screen).\n\nAvailable Commands:\n* webdiff: Web diff client\n* cluster: Extract action clusters\n* dotdiff: A dot diff client\n* htmldiff: Dump diff as HTML in stdout\n* list: List matchers, generators, clients and properties\n* parse: Parse file and dump result.\n* swingdiff: A swing diff client\n* textdiff: Dump actions in a textual format.\n* axmldiff: Dump annotated xml tree\n')

# %%
result
# Out:
# CompletedProcess(args=['/Users/hungnguyen/dacn/untitled folder/gumtree-4.0.0-beta4/bin/gumtree', '--help'], returncode=1, stdout='', stderr='The operation couldn’t be completed. Unable to locate a Java Runtime.\nPlease visit http://www.java.com for information on installing Java.\n\n')
